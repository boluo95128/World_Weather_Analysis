# %%
# Import dependencies
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 623

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key


# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-" * 25)

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_country = city_weather["sys"]["country"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches=0
        try:
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches=0
            
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country":city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Rain(Inches)": city_rain_inches,
                          "Snow(Inches)": city_snow_inches                    
                         })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | arraial do cabo
# Processing Record 2 of Set 1 | qafsah
# City not found. Skipping...
# Processing Record 3 of Set 1 | san patricio
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | mar del plata
# Processing Record 6 of Set 1 | fort dix
# Processing Record 7 of Set 1 | beyneu
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | upernavik
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | turukhansk
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | ilhabela
# Processing Record 16 of Set 1 | prince rupert
# Processing Record 17 of Set 1 | cherskiy
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | nantucket
# Processing Record 20 of Set 1 | benjamin constant
# Processing Record 21 of Set 1 | bereda
# Processing Record 22 of Set 1 | yelan-koleno
# Processing Record 23 of Set 1 | nuevitas
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 26 of Set 1 | karratha
# Processing Record 27 of Set 1 | luderitz
# Processing Record 28 of Set 1 | bijie
# Processing Record 29 of Set 1 | esmeraldas
# Processing Record 30 of Set 1 | alofi
# Processing Record 31 of Set 1 | wajid
# Processing Record 32 of Set 1 | kodiak
# Processing Record 33 of Set 1 | dunedin
# Processing Record 34 of Set 1 | mnogovershinnyy
# Processing Record 35 of Set 1 | kailua
# Processing Record 36 of Set 1 | kichera
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | freeport
# Processing Record 39 of Set 1 | trelew
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | yulara
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | luba
# Processing Record 45 of Set 1 | muli
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | tuatapere
# Processing Record 48 of Set 1 | thompson
# Processing Record 49 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 1 | constitucion
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | itoman
# Processing Record 3 of Set 2 | shihezi
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | moose factory
# Processing Record 6 of Set 2 | roxas
# Processing Record 7 of Set 2 | bairiki
# Processing Record 8 of Set 2 | lasa
# Processing Record 9 of Set 2 | turkmenabat
# Processing Record 10 of Set 2 | copiapo
# Processing Record 11 of Set 2 | the valley
# Processing Record 12 of Set 2 | coihaique
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | faanui
# Processing Record 15 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | georgetown
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | muzhi
# Processing Record 20 of Set 2 | busselton
# Processing Record 21 of Set 2 | jamestown
# Processing Record 22 of Set 2 | foz
# Processing Record 23 of Set 2 | saldanha
# Processing Record 24 of Set 2 | nikolskoye
# Processing Record 25 of Set 2 | frankenberg
# Processing Record 26 of Set 2 | hobart
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | treinta y tres
# Processing Record 29 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 2 | tuktoyaktuk
# Processing Record 31 of Set 2 | los llanos de aridane
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | la ronge
# Processing Record 34 of Set 2 | portree
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | kahului
# Processing Record 37 of Set 2 | aksarka
# Processing Record 38 of Set 2 | kodinsk
# Processing Record 39 of Set 2 | chokurdakh
# Processing Record 40 of Set 2 | sitka
# Processing Record 41 of Set 2 | cabo san lucas
# Processing Record 42 of Set 2 | east london
# Processing Record 43 of Set 2 | ribeira grande
# Processing Record 44 of Set 2 | lavrentiya
# Processing Record 45 of Set 2 | lata
# Processing Record 46 of Set 2 | oxford
# Processing Record 47 of Set 2 | pangody
# Processing Record 48 of Set 2 | ankang
# Processing Record 49 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 2 | haines junction
# Processing Record 1 of Set 3 | port elizabeth
# Processing Record 2 of Set 3 | dikson
# Processing Record 3 of Set 3 | lebu
# Processing Record 4 of Set 3 | nome
# Processing Record 5 of Set 3 | mastic beach
# Processing Record 6 of Set 3 | hamilton
# Processing Record 7 of Set 3 | andapa
# Processing Record 8 of Set 3 | saint-philippe
# Processing Record 9 of Set 3 | roald
# Processing Record 10 of Set 3 | port augusta
# Processing Record 11 of Set 3 | nizhnevartovsk
# Processing Record 12 of Set 3 | asfi
# Processing Record 13 of Set 3 | portland
# Processing Record 14 of Set 3 | san pedro
# Processing Record 15 of Set 3 | kelowna
# Processing Record 16 of Set 3 | grimshaw
# Processing Record 17 of Set 3 | redlands
# Processing Record 18 of Set 3 | kununurra
# Processing Record 19 of Set 3 | klaksvik
# Processing Record 20 of Set 3 | seoul
# Processing Record 21 of Set 3 | kaitangata
# Processing Record 22 of Set 3 | saint-georges
# Processing Record 23 of Set 3 | airai
# Processing Record 24 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 3 | ponta do sol
# Processing Record 26 of Set 3 | bilibino
# Processing Record 27 of Set 3 | okmulgee
# Processing Record 28 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 3 | ouallam
# Processing Record 30 of Set 3 | aleksandrov gay
# Processing Record 31 of Set 3 | vanimo
# Processing Record 32 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 3 | troitskoye
# Processing Record 34 of Set 3 | teguldet
# Processing Record 35 of Set 3 | castro
# Processing Record 36 of Set 3 | norman wells
# Processing Record 37 of Set 3 | ruteng
# Processing Record 38 of Set 3 | vila franca do campo
# Processing Record 39 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 3 | saskylakh
# Processing Record 41 of Set 3 | yamada
# Processing Record 42 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 3 | qaanaaq
# Processing Record 44 of Set 3 | port lincoln
# Processing Record 45 of Set 3 | pevek
# Processing Record 46 of Set 3 | iralaya
# Processing Record 47 of Set 3 | byron bay
# Processing Record 48 of Set 3 | esperance
# Processing Record 49 of Set 3 | olbia
# Processing Record 50 of Set 3 | llangefni
# Processing Record 1 of Set 4 | severo-kurilsk
# Processing Record 2 of Set 4 | padang
# Processing Record 3 of Set 4 | urumqi
# Processing Record 4 of Set 4 | montrose
# Processing Record 5 of Set 4 | salalah
# Processing Record 6 of Set 4 | luganville
# Processing Record 7 of Set 4 | churapcha
# Processing Record 8 of Set 4 | longyearbyen
# Processing Record 9 of Set 4 | lorengau
# Processing Record 10 of Set 4 | ust-nera
# Processing Record 11 of Set 4 | mandurah
# Processing Record 12 of Set 4 | montenegro
# Processing Record 13 of Set 4 | khatanga
# Processing Record 14 of Set 4 | aklavik
# Processing Record 15 of Set 4 | grand gaube
# Processing Record 16 of Set 4 | springfield
# Processing Record 17 of Set 4 | souillac
# Processing Record 18 of Set 4 | tautira
# Processing Record 19 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 4 | eyl
# Processing Record 21 of Set 4 | filadelfia
# Processing Record 22 of Set 4 | campina verde
# Processing Record 23 of Set 4 | san quintin
# Processing Record 24 of Set 4 | leeuwarden
# Processing Record 25 of Set 4 | bethel
# Processing Record 26 of Set 4 | hami
# Processing Record 27 of Set 4 | chuy
# Processing Record 28 of Set 4 | college
# Processing Record 29 of Set 4 | tasiilaq
# Processing Record 30 of Set 4 | bella union
# Processing Record 31 of Set 4 | leningradskiy
# Processing Record 32 of Set 4 | mardan
# Processing Record 33 of Set 4 | talnakh
# Processing Record 34 of Set 4 | bambous virieux
# Processing Record 35 of Set 4 | bathsheba
# Processing Record 36 of Set 4 | alghero
# Processing Record 37 of Set 4 | villazon
# Processing Record 38 of Set 4 | motygino
# Processing Record 39 of Set 4 | formosa
# Processing Record 40 of Set 4 | geraldton
# Processing Record 41 of Set 4 | ixtapa
# Processing Record 42 of Set 4 | codajas
# Processing Record 43 of Set 4 | luena
# Processing Record 44 of Set 4 | paamiut
# Processing Record 45 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 4 | tanjong sepat
# City not found. Skipping...
# Processing Record 47 of Set 4 | port-de-paix
# City not found. Skipping...
# Processing Record 48 of Set 4 | hannibal
# Processing Record 49 of Set 4 | bacolod
# Processing Record 50 of Set 4 | gritsovskiy
# Processing Record 1 of Set 5 | saint george
# Processing Record 2 of Set 5 | lagoa
# Processing Record 3 of Set 5 | puri
# Processing Record 4 of Set 5 | dawei
# Processing Record 5 of Set 5 | capitao poco
# Processing Record 6 of Set 5 | mae hong son
# Processing Record 7 of Set 5 | kruisfontein
# Processing Record 8 of Set 5 | oranjemund
# Processing Record 9 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 5 | melton
# Processing Record 11 of Set 5 | bluff
# Processing Record 12 of Set 5 | coquimbo
# Processing Record 13 of Set 5 | karamea
# City not found. Skipping...
# Processing Record 14 of Set 5 | nueva gerona
# Processing Record 15 of Set 5 | meulaboh
# Processing Record 16 of Set 5 | new norfolk
# Processing Record 17 of Set 5 | havre-saint-pierre
# Processing Record 18 of Set 5 | korla
# Processing Record 19 of Set 5 | port hardy
# Processing Record 20 of Set 5 | gat
# Processing Record 21 of Set 5 | siilinjarvi
# Processing Record 22 of Set 5 | saint-joseph
# Processing Record 23 of Set 5 | cidreira
# Processing Record 24 of Set 5 | port moresby
# Processing Record 25 of Set 5 | vasterhaninge
# Processing Record 26 of Set 5 | sao filipe
# Processing Record 27 of Set 5 | namibe
# Processing Record 28 of Set 5 | novyy svit
# Processing Record 29 of Set 5 | shingu
# Processing Record 30 of Set 5 | yarada
# Processing Record 31 of Set 5 | ilulissat
# Processing Record 32 of Set 5 | funtua
# Processing Record 33 of Set 5 | cairns
# Processing Record 34 of Set 5 | tromso
# Processing Record 35 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 36 of Set 5 | ballangen
# Processing Record 37 of Set 5 | beloha
# Processing Record 38 of Set 5 | calvinia
# Processing Record 39 of Set 5 | pringsewu
# Processing Record 40 of Set 5 | ostrovnoy
# Processing Record 41 of Set 5 | sur
# Processing Record 42 of Set 5 | yaan
# Processing Record 43 of Set 5 | ambon
# Processing Record 44 of Set 5 | bengkulu
# Processing Record 45 of Set 5 | provideniya
# Processing Record 46 of Set 5 | nanortalik
# Processing Record 47 of Set 5 | trinidad
# Processing Record 48 of Set 5 | tabou
# Processing Record 49 of Set 5 | laiwu
# Processing Record 50 of Set 5 | torbay
# Processing Record 1 of Set 6 | khorixas
# Processing Record 2 of Set 6 | husavik
# Processing Record 3 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 6 | vila
# Processing Record 5 of Set 6 | goma
# Processing Record 6 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 7 of Set 6 | toora-khem
# Processing Record 8 of Set 6 | dingle
# Processing Record 9 of Set 6 | road town
# Processing Record 10 of Set 6 | bambanglipuro
# Processing Record 11 of Set 6 | carnarvon
# Processing Record 12 of Set 6 | nuuk
# Processing Record 13 of Set 6 | coahuayana
# Processing Record 14 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 15 of Set 6 | kolyshley
# Processing Record 16 of Set 6 | saint-pierre
# Processing Record 17 of Set 6 | mahebourg
# Processing Record 18 of Set 6 | praia da vitoria
# Processing Record 19 of Set 6 | ipixuna
# Processing Record 20 of Set 6 | acarau
# Processing Record 21 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 22 of Set 6 | sirfa
# City not found. Skipping...
# Processing Record 23 of Set 6 | brigantine
# Processing Record 24 of Set 6 | karachi
# Processing Record 25 of Set 6 | phonhong
# Processing Record 26 of Set 6 | aksha
# Processing Record 27 of Set 6 | peniche
# Processing Record 28 of Set 6 | sidvokodvo
# Processing Record 29 of Set 6 | barraute
# Processing Record 30 of Set 6 | sinnamary
# Processing Record 31 of Set 6 | bilma
# Processing Record 32 of Set 6 | akyab
# Processing Record 33 of Set 6 | laguna de duero
# Processing Record 34 of Set 6 | tura
# Processing Record 35 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 36 of Set 6 | veraval
# Processing Record 37 of Set 6 | abha
# Processing Record 38 of Set 6 | sao borja
# Processing Record 39 of Set 6 | black diamond
# Processing Record 40 of Set 6 | halifax
# Processing Record 41 of Set 6 | hvizd
# Processing Record 42 of Set 6 | sakakah
# Processing Record 43 of Set 6 | carahue
# Processing Record 44 of Set 6 | priargunsk
# Processing Record 45 of Set 6 | abu dhabi
# Processing Record 46 of Set 6 | aswan
# Processing Record 47 of Set 6 | chumikan
# Processing Record 48 of Set 6 | hofn
# Processing Record 49 of Set 6 | sarangani
# Processing Record 50 of Set 6 | ahuimanu
# Processing Record 1 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 7 | krasnogorskoye
# Processing Record 3 of Set 7 | namatanai
# Processing Record 4 of Set 7 | ganzhou
# Processing Record 5 of Set 7 | fortuna
# Processing Record 6 of Set 7 | sobolevo
# Processing Record 7 of Set 7 | neka
# Processing Record 8 of Set 7 | cap malheureux
# Processing Record 9 of Set 7 | hasaki
# Processing Record 10 of Set 7 | ancud
# Processing Record 11 of Set 7 | lufilufi
# Processing Record 12 of Set 7 | itaueira
# Processing Record 13 of Set 7 | riyadh
# Processing Record 14 of Set 7 | kungurtug
# Processing Record 15 of Set 7 | touros
# Processing Record 16 of Set 7 | campbell river
# Processing Record 17 of Set 7 | ketchikan
# Processing Record 18 of Set 7 | magadan
# Processing Record 19 of Set 7 | tashla
# Processing Record 20 of Set 7 | putyatino
# Processing Record 21 of Set 7 | chenzhou
# Processing Record 22 of Set 7 | uzumlu
# City not found. Skipping...
# Processing Record 23 of Set 7 | impfondo
# Processing Record 24 of Set 7 | egersund
# Processing Record 25 of Set 7 | allapalli
# Processing Record 26 of Set 7 | wewak
# Processing Record 27 of Set 7 | shelui
# Processing Record 28 of Set 7 | znamenskoye
# Processing Record 29 of Set 7 | hambantota
# Processing Record 30 of Set 7 | muroto
# Processing Record 31 of Set 7 | batagay
# Processing Record 32 of Set 7 | hvolsvollur
# Processing Record 33 of Set 7 | bonthe
# Processing Record 34 of Set 7 | bintulu
# Processing Record 35 of Set 7 | kuryk
# Processing Record 36 of Set 7 | kaliua
# Processing Record 37 of Set 7 | flinders
# Processing Record 38 of Set 7 | damietta
# Processing Record 39 of Set 7 | mayo
# Processing Record 40 of Set 7 | valle de banderas
# Processing Record 41 of Set 7 | alyangula
# Processing Record 42 of Set 7 | ayan
# Processing Record 43 of Set 7 | passa quatro
# Processing Record 44 of Set 7 | sungaipenuh
# Processing Record 45 of Set 7 | kapuskasing
# Processing Record 46 of Set 7 | verkhoyansk
# Processing Record 47 of Set 7 | quatre cocos
# Processing Record 48 of Set 7 | ulladulla
# Processing Record 49 of Set 7 | pangnirtung
# Processing Record 50 of Set 7 | manta
# Processing Record 1 of Set 8 | bandarbeyla
# Processing Record 2 of Set 8 | hay river
# Processing Record 3 of Set 8 | komsomolskiy
# Processing Record 4 of Set 8 | moussoro
# Processing Record 5 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 8 | north bend
# Processing Record 7 of Set 8 | fairbanks
# Processing Record 8 of Set 8 | ayagoz
# Processing Record 9 of Set 8 | daru
# Processing Record 10 of Set 8 | nador
# Processing Record 11 of Set 8 | hokitika
# Processing Record 12 of Set 8 | conway
# Processing Record 13 of Set 8 | lobva
# Processing Record 14 of Set 8 | rayong
# Processing Record 15 of Set 8 | cabedelo
# Processing Record 16 of Set 8 | kapoeta
# Processing Record 17 of Set 8 | kavieng
# Processing Record 18 of Set 8 | netarhat
# Processing Record 19 of Set 8 | arrecife
# Processing Record 20 of Set 8 | west bay
# Processing Record 21 of Set 8 | broken hill
# Processing Record 22 of Set 8 | nago
# Processing Record 23 of Set 8 | pangoa
# Processing Record 24 of Set 8 | komatipoort
# Processing Record 25 of Set 8 | drumheller
# Processing Record 26 of Set 8 | carupano
# Processing Record 27 of Set 8 | itarema
# Processing Record 28 of Set 8 | palmer
# Processing Record 29 of Set 8 | gabrovo
# Processing Record 30 of Set 8 | san andres
# Processing Record 31 of Set 8 | kavaratti
# Processing Record 32 of Set 8 | koshurnikovo
# Processing Record 33 of Set 8 | caravelas
# Processing Record 34 of Set 8 | benguela
# Processing Record 35 of Set 8 | naze
# Processing Record 36 of Set 8 | kolokani
# Processing Record 37 of Set 8 | san francisco
# Processing Record 38 of Set 8 | sechura
# Processing Record 39 of Set 8 | soe
# Processing Record 40 of Set 8 | rawson
# Processing Record 41 of Set 8 | san juan
# Processing Record 42 of Set 8 | vardo
# Processing Record 43 of Set 8 | sinazongwe
# Processing Record 44 of Set 8 | port blair
# Processing Record 45 of Set 8 | mehamn
# Processing Record 46 of Set 8 | daokou
# Processing Record 47 of Set 8 | kulhudhuffushi
# Processing Record 48 of Set 8 | jalu
# Processing Record 49 of Set 8 | san policarpo
# Processing Record 50 of Set 8 | rio gallegos
# Processing Record 1 of Set 9 | asau
# Processing Record 2 of Set 9 | lebedinyy
# Processing Record 3 of Set 9 | acajutla
# Processing Record 4 of Set 9 | maceio
# Processing Record 5 of Set 9 | sarahan
# Processing Record 6 of Set 9 | vanavara
# Processing Record 7 of Set 9 | adrar
# Processing Record 8 of Set 9 | houma
# Processing Record 9 of Set 9 | kasongo-lunda
# Processing Record 10 of Set 9 | bajil
# Processing Record 11 of Set 9 | forestville
# Processing Record 12 of Set 9 | cluj-napoca
# Processing Record 13 of Set 9 | anadyr
# Processing Record 14 of Set 9 | sola
# Processing Record 15 of Set 9 | victoria
# Processing Record 16 of Set 9 | narwana
# Processing Record 17 of Set 9 | kulu
# Processing Record 18 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 9 | sorong
# Processing Record 20 of Set 9 | bowmore
# Processing Record 21 of Set 9 | corvallis
# Processing Record 22 of Set 9 | sabinas hidalgo
# Processing Record 23 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 24 of Set 9 | sisimiut
# Processing Record 25 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 9 | ola
# Processing Record 27 of Set 9 | dongsheng
# Processing Record 28 of Set 9 | pisco
# Processing Record 29 of Set 9 | gombong
# Processing Record 30 of Set 9 | gorontalo
# Processing Record 31 of Set 9 | tiksi
# Processing Record 32 of Set 9 | galveston
# Processing Record 33 of Set 9 | kendari
# Processing Record 34 of Set 9 | belaya gora
# Processing Record 35 of Set 9 | afmadu
# City not found. Skipping...
# Processing Record 36 of Set 9 | silopi
# Processing Record 37 of Set 9 | rognan
# Processing Record 38 of Set 9 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 39 of Set 9 | masunga
# Processing Record 40 of Set 9 | codrington
# Processing Record 41 of Set 9 | muros
# Processing Record 42 of Set 9 | teya
# Processing Record 43 of Set 9 | iisalmi
# Processing Record 44 of Set 9 | tunceli
# Processing Record 45 of Set 9 | aginskoye
# Processing Record 46 of Set 9 | akranes
# Processing Record 47 of Set 9 | westport
# Processing Record 48 of Set 9 | shubarshi
# Processing Record 49 of Set 9 | charthawal
# Processing Record 50 of Set 9 | poum
# Processing Record 1 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 10 | turayf
# Processing Record 3 of Set 10 | alberton
# Processing Record 4 of Set 10 | olinda
# Processing Record 5 of Set 10 | port hueneme
# Processing Record 6 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 10 | narsaq
# Processing Record 8 of Set 10 | mogzon
# Processing Record 9 of Set 10 | necochea
# Processing Record 10 of Set 10 | abbeville
# Processing Record 11 of Set 10 | gravdal
# Processing Record 12 of Set 10 | valday
# Processing Record 13 of Set 10 | kalmunai
# Processing Record 14 of Set 10 | fort saint james
# Processing Record 15 of Set 10 | nanpiao
# Processing Record 16 of Set 10 | grindavik
# Processing Record 17 of Set 10 | tabukiniberu
# City not found. Skipping...
# Processing Record 18 of Set 10 | sosnovka
# Processing Record 19 of Set 10 | nishihara
# Processing Record 20 of Set 10 | port macquarie
# Processing Record 21 of Set 10 | nanga eboko
# Processing Record 22 of Set 10 | yumen
# Processing Record 23 of Set 10 | ojinaga
# Processing Record 24 of Set 10 | kieta
# Processing Record 25 of Set 10 | kamaishi
# Processing Record 26 of Set 10 | qaqortoq
# Processing Record 27 of Set 10 | nassau
# Processing Record 28 of Set 10 | benghazi
# Processing Record 29 of Set 10 | ust-kulom
# Processing Record 30 of Set 10 | srednekolymsk
# Processing Record 31 of Set 10 | santa maria da vitoria
# Processing Record 32 of Set 10 | gweta
# Processing Record 33 of Set 10 | deputatskiy
# Processing Record 34 of Set 10 | irece
# Processing Record 35 of Set 10 | ngunguru
# Processing Record 36 of Set 10 | dromolaxia
# Processing Record 37 of Set 10 | bocos
# Processing Record 38 of Set 10 | mombasa
# Processing Record 39 of Set 10 | brae
# Processing Record 40 of Set 10 | cumanayagua
# Processing Record 41 of Set 10 | pando
# Processing Record 42 of Set 10 | santa fe
# Processing Record 43 of Set 10 | clovis
# Processing Record 44 of Set 10 | misawa
# Processing Record 45 of Set 10 | siirt
# Processing Record 46 of Set 10 | eagle pass
# Processing Record 47 of Set 10 | altay
# Processing Record 48 of Set 10 | sao joao da barra
# Processing Record 49 of Set 10 | patacamaya
# Processing Record 50 of Set 10 | danjiangkou
# Processing Record 1 of Set 11 | flin flon
# Processing Record 2 of Set 11 | avera
# Processing Record 3 of Set 11 | balclutha
# Processing Record 4 of Set 11 | santa rosa
# Processing Record 5 of Set 11 | mulege
# Processing Record 6 of Set 11 | watertown
# Processing Record 7 of Set 11 | omsukchan
# Processing Record 8 of Set 11 | dakoro
# Processing Record 9 of Set 11 | svetlogorsk
# Processing Record 10 of Set 11 | genhe
# Processing Record 11 of Set 11 | malatya
# Processing Record 12 of Set 11 | anloga
# Processing Record 13 of Set 11 | payakumbuh
# Processing Record 14 of Set 11 | bonneville
# Processing Record 15 of Set 11 | kidal
# Processing Record 16 of Set 11 | bima
# Processing Record 17 of Set 11 | laguna
# Processing Record 18 of Set 11 | udachnyy
# Processing Record 19 of Set 11 | awjilah
# Processing Record 20 of Set 11 | bubaque
# Processing Record 21 of Set 11 | mount gambier
# Processing Record 22 of Set 11 | ranfurly
# Processing Record 23 of Set 11 | monster
# Processing Record 24 of Set 11 | kainantu
# Processing Record 25 of Set 11 | broome
# Processing Record 26 of Set 11 | alekseyevsk
# Processing Record 27 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 11 | emerald
# Processing Record 29 of Set 11 | barra do garcas
# Processing Record 30 of Set 11 | mitsamiouli
# Processing Record 31 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 32 of Set 11 | raahe
# Processing Record 33 of Set 11 | szigetvar
# Processing Record 34 of Set 11 | nsanje
# Processing Record 35 of Set 11 | raga
# Processing Record 36 of Set 11 | paka
# Processing Record 37 of Set 11 | pauini
# Processing Record 38 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 39 of Set 11 | port keats
# Processing Record 40 of Set 11 | aquiraz
# Processing Record 41 of Set 11 | saint-leu
# Processing Record 42 of Set 11 | liozon
# Processing Record 43 of Set 11 | puerto colombia
# Processing Record 44 of Set 11 | tilichiki
# Processing Record 45 of Set 11 | iskateley
# Processing Record 46 of Set 11 | angoche
# Processing Record 47 of Set 11 | port hedland
# Processing Record 48 of Set 11 | berezovyy
# Processing Record 49 of Set 11 | chenghai
# Processing Record 50 of Set 11 | russellville
# Processing Record 1 of Set 12 | sajanan
# Processing Record 2 of Set 12 | makakilo city
# Processing Record 3 of Set 12 | el grullo
# Processing Record 4 of Set 12 | along
# Processing Record 5 of Set 12 | yerbabuena
# Processing Record 6 of Set 12 | safford
# Processing Record 7 of Set 12 | riohacha
# Processing Record 8 of Set 12 | ekhabi
# Processing Record 9 of Set 12 | tamandare
# Processing Record 10 of Set 12 | anjar
# Processing Record 11 of Set 12 | haimen
# Processing Record 12 of Set 12 | mahina
# Processing Record 13 of Set 12 | bolonchen
# City not found. Skipping...
# Processing Record 14 of Set 12 | half moon bay
# Processing Record 15 of Set 12 | umea
# Processing Record 16 of Set 12 | katsuura
# Processing Record 17 of Set 12 | clarence town
# Processing Record 18 of Set 12 | waipawa
# Processing Record 19 of Set 12 | grafton
# Processing Record 20 of Set 12 | yancheng
# Processing Record 21 of Set 12 | plouzane
# Processing Record 22 of Set 12 | arona
# Processing Record 23 of Set 12 | aksu
# Processing Record 24 of Set 12 | alexandria
# Processing Record 25 of Set 12 | swan hill
# Processing Record 26 of Set 12 | honiara
# Processing Record 27 of Set 12 | pouembout
# Processing Record 28 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 29 of Set 12 | kloulklubed
# Processing Record 30 of Set 12 | beringovskiy
# Processing Record 31 of Set 12 | acucena
# Processing Record 32 of Set 12 | edgewater
# Processing Record 33 of Set 12 | gurskoye
# City not found. Skipping...
# Processing Record 34 of Set 12 | tecoanapa
# Processing Record 35 of Set 12 | mizdah
# Processing Record 36 of Set 12 | jasper
# Processing Record 37 of Set 12 | axim
# Processing Record 38 of Set 12 | trairi
# Processing Record 39 of Set 12 | nemuro
# Processing Record 40 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 41 of Set 12 | tabas
# Processing Record 42 of Set 12 | springville
# Processing Record 43 of Set 12 | zyryanskoye
# Processing Record 44 of Set 12 | mbandaka
# Processing Record 45 of Set 12 | lamu
# Processing Record 46 of Set 12 | kijang
# Processing Record 47 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 48 of Set 12 | te anau
# Processing Record 49 of Set 12 | catamarca
# Processing Record 50 of Set 12 | verkhnyaya toyma
# Processing Record 1 of Set 13 | bogorodskoye
# Processing Record 2 of Set 13 | jiaojiang
# Processing Record 3 of Set 13 | vostok
# Processing Record 4 of Set 13 | kefamenanu
# Processing Record 5 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 6 of Set 13 | victor harbor
# Processing Record 7 of Set 13 | barabinsk
# Processing Record 8 of Set 13 | villacarrillo
# Processing Record 9 of Set 13 | samarai
# Processing Record 10 of Set 13 | pacific grove
# Processing Record 11 of Set 13 | yar-sale
# Processing Record 12 of Set 13 | san felipe
# Processing Record 13 of Set 13 | khartoum
# Processing Record 14 of Set 13 | pochutla
# Processing Record 15 of Set 13 | mankono
# Processing Record 16 of Set 13 | lazdijai
# Processing Record 17 of Set 13 | isangel
# Processing Record 18 of Set 13 | goderich
# Processing Record 19 of Set 13 | storm lake
# Processing Record 20 of Set 13 | murray bridge
# Processing Record 21 of Set 13 | pedro juan caballero
# Processing Record 22 of Set 13 | atambua
# Processing Record 23 of Set 13 | lingao
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                      City Country    Lat     Lng  Max Temp  Humidity  \
# 0         Arraial Do Cabo      BR -22.97  -42.03     73.17        86
# 1            San Patricio      MX  19.22 -104.70     78.62        70
# 2                   Vaini      TO -21.20 -175.20     77.00        88
# 3           Mar Del Plata      AR -38.00  -57.56     53.01        93
# 4                Fort Dix      US  40.03  -74.62     68.00       100
# ..                    ...     ...    ...     ...       ...       ...
# 573            Storm Lake      US  42.64  -95.21     66.20        88
# 574         Murray Bridge      AU -35.12  139.27     55.99        79
# 575  Pedro Juan Caballero      PY -22.55  -55.73     63.79        61
# 576               Atambua      ID  -9.11  124.89     83.14        54
# 577                Lingao      CN  19.91  109.69     93.51        50
#
#      Cloudiness  Wind Speed Current Description  Rain(Inches)  Snow(Inches)
# 0             0       10.36           clear sky          0.00             0
# 1            77        1.86       broken clouds          0.00             0
# 2            75        4.70       broken clouds          0.00             0
# 3           100       17.34     overcast clouds          0.00             0
# 4             1        3.20           clear sky          0.00             0
# ..          ...         ...                 ...           ...           ...
# 573           1        3.36           clear sky          0.00             0
# 574          45        7.00          light rain          0.33             0
# 575           0        9.13           clear sky          0.00             0
# 576           0        2.21           clear sky          0.00             0
# 577          69        3.11       broken clouds          0.00             0
#
# [578 rows x 11 columns]

# %%
city_data_with_rain_df=city_data_df.loc[city_data_df["Rain(Inches)"]>0]

# %%
city_data_with_rain_df
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 25           Bijie      CN  27.31  105.29     75.72        78         100
# 27           Alofi      NU -19.06 -169.92     77.00        78          97
# 51           Roxas      PH  11.59  122.75     86.63        73          84
# 59          Faanui      PF -16.48 -151.75     78.39        85         100
# 67        Saldanha      ZA -33.01   17.94     57.20        93           4
# ..             ...     ...    ...     ...       ...       ...         ...
# 544           Axim      GH   4.87   -2.24     76.57        88          97
# 557      Jiaojiang      CN  28.68  121.44     75.99        80         100
# 558         Vostok      RU  46.49  135.88     48.81        99         100
# 568       Pochutla      MX  15.74  -96.47     80.01        86          99
# 574  Murray Bridge      AU -35.12  139.27     55.99        79          45
#
#      Wind Speed Current Description  Rain(Inches)  Snow(Inches)
# 25         5.08       moderate rain          1.22             0
# 27        11.41          light rain          0.15             0
# 51         9.55       moderate rain          1.47             0
# 59        18.95          light rain          0.29             0
# 67        11.41          light rain          0.49             0
# ..          ...                 ...           ...           ...
# 544       10.33          light rain          0.18             0
# 557        5.86       moderate rain          1.21             0
# 558        7.23       moderate rain          2.74             0
# 568        2.46          light rain          0.78             0
# 574        7.00          light rain          0.33             0
#
# [76 rows x 11 columns]

# %%
city_data_with_snow_df=city_data_df.loc[city_data_df["Snow(Inches)"]>0]
city_data_with_snow_df
# Out:
# Empty DataFrame
# Columns: [City, Country, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Current Description, Rain(Inches), Snow(Inches)]
# Index: []

# %%
# Create the output file (CSV).
output_data_file = "challenge_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
